# %%
import vaex as vx

# %%
ds = vx.datasets.helmi_de_zeeuw.fetch()

# %%
ds["Lz", "E"].plot_bq(f="log", tool_select=True)
# Out:
# /Users/users/breddels/src/vaex/python/vaex/dataset.py:1606: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   mask[i1:i2] = mode_function(None if self.dataset.mask is None else self.dataset.mask[i1:i2], block == 1)
# /Users/users/breddels/src/vaex/python/vaex/dataset.py:192: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   blocks = [block[mask[i1:i2]] for block in blocks]

# %%
ds["x", "y"].plot_bq(f="log", tool_select=True)
